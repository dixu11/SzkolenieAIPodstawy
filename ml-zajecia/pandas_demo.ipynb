# %%
import pandas as pd

df = pd.read_csv('orders_raw.csv')
df

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %%
columns = df.columns
for column in columns:
    print('Kolumna : ' , column)

# %%
df[df.columns[0]]

# %%
df[ ['Price','Quantity'] ]

# %%
print(type(df))
print(type(df['Price']))

# %%
df = df[df['Price']< 200]
df

# %%
df['Quantity'].value_counts()

# %%
df.shape

# %%
df = df[df['Quantity'] > 0 ]
df.shape

# %%
df.head()

# %%
df.iloc[1]

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %%
df.shape

# %%
# przy skomplikowanych warunkach muszą być nawiasy między | oraz &
df[(df['Category'] == 'Electronics') |  (df['Category'] == 'Furniture') ]  # or = |   and = &

# %%
df.groupby('Category')['Price'].sum()

# %%
df['Person Country'] = df['CustomerName'] + ' ' + df['Country']
df

# %%
df.to_csv('order_v2.csv')
