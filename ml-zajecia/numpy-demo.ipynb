# %%
import numpy as np

# %%
lista = [123,45,53,4,11,3,-7,33]
tablica = np.array([123,45,53,4,11,3,-7,33])

print(lista)
print(tablica)
print(type(lista))
print(type(tablica))
# Out:
# [123, 45, 53, 4, 11, 3, -7, 33]
# [123  45  53   4  11   3  -7  33]
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
# lista powiela elementy(rośnie) a tablica wykonuje operacje na każdej wartości modyfikując ją
print(lista *2)
print(tablica * 2)
# Out:
# [123, 45, 53, 4, 11, 3, -7, 33, 123, 45, 53, 4, 11, 3, -7, 33]
# [246  90 106   8  22   6 -14  66]

# %%
print(len(lista))
print(tablica.shape)

print([[10,20],[30,40]])
array2D = np.array([[10,20,30],[30,40,40]])
array2D.shape
# Out:
# 8
# (8,)
# [[10, 20], [30, 40]]
# (2, 3)

# %%
tablica > 0
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True])

# %%
tablica[2:4]
# Out:
# array([53,  4])

# %%
tablica[tablica > 0]
# Out:
# array([123,  45,  53,   4,  11,   3,  33])

# %%
tablica
# Out:
# array([123,  45,  53,   4,  11,   3,  -7,  33])

# %%
tablica = tablica[tablica>0]
tablica
# Out:
# array([123,  45,  53,   4,  11,   3,  33])

# %%
#array2D = np.array([[10,20,30],[30,40,40]])
array2D[:,1]
# Out:
# array([20, 40])

# %%
tablica
# Out:
# array([123,  45,  53,   4,  11,   3,  33])

# %%
tablica2 = tablica[:3]

# %%
tablica2[0] = 7
tablica2
# Out:
# array([ 7, 45, 53])

# %%
tablica
# Out:
# array([ 7, 45, 53,  4, 11,  3, 33])

# %%
#aby nie dostawać widoku na część danych ale realną kopię, która możemy edytować osobno : copy()
tablica2 = tablica[:3].copy()

# %%
tablica = np.append(tablica,tablica)
tablica = np.append(tablica,np.array([-2,-3]))

tablica
# Out:
# array([ 7, 45, 53,  4, 11,  3, 33,  7, 45, 53,  4, 11,  3, 33, -2, -3])

# %%
print(tablica.mean())
print(tablica.max())
print(tablica.min())
print(tablica.std())
print(np.abs(tablica))
# Out:
# 19.1875
# 53
# -3
# 19.934952815344207
# [ 7 45 53  4 11  3 33  7 45 53  4 11  3 33  2  3]
